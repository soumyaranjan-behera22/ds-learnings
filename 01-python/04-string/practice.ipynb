# %%
str = "python"
print(str[2])
# Out:
# t

# %% [markdown]
# slicing in strings

# %%
str = "python"
i=str[1:]
j=str[:]
k=str[:5]
l=str[-4:-1] #negative indexing of string like n=-1, o=-2, h=-3 etc
print(i)
print(j)
print(k)
print(l)
# Out:
# ython
# python
# pytho
# tho
