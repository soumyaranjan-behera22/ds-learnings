# %% [markdown]
# Practice Problems (Set 2)
# 1.Print multiplication table for any number . [using
# while ]
# 2.Print odd numbers from 1 to 10, using continue. [using while]
# 3.Count vowels in a word. [using for]
# 4.Sum of first natural numbers. [using  for]

# %%
# 4
i=int(input("enter number"))
sum=0
for num in range(1,i+1): # if i =4 then sum = 1+2+3+4
    sum+=num
print(sum)
# Out:
# 10

# %%
# 3
word="hello world"
count=0
for val in word :
    if(val=="a" or val=="e" or val=="i" or val=="o" or val=="u"):
        count+=1
print(f" vowels exist {count} times")
# Out:
#  vowels exist 0 times

# %%
#1
n=int(input("enter a number"))
i =1
while(i<=10):
    res =n*i
    i+=1
    print(res)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
#2
i=1
while(i<=10):
    if(i%2==0):
        i+=1
        continue
    print(i)
    i+=1
# Out:
# 1
# 3
# 5
# 7
# 9
