# %% [markdown]
# USER AUTHENTICATION SYSTEM
# login(), logot(), authentication()

# %% [markdown]
# LEVEL 8 — Ultra Pro System Design
# 40. Library Management System
# Features:
# add_book()
# issue_book()
# return_book()
# show_books()
#
# 41. ATM Machine System
# Features:
# check_balance()
# withdraw()
# deposit()
# pin_authentication()
#
# 42. Student Management System
# Features:
# add_student()
# delete_student()
# update_student()
# show_student()
#
# 43. Shopping Cart System
# Features:
# add_product()
# remove_product()
# calculate_total()
#
# 44. Parking Lot System
# Features:
# park_vehicle()
# remove_vehicle()
# check_free_slots()
#
# 45. Hotel Room Booking System
# Features:
# book_room()
# cancel_room()
# show_available_rooms()
