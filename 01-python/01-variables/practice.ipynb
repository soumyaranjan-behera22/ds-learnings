# %%
age=10
print(f"hello {age}")
# Out:
# hello 10

# %%
word = "artificial intelligence"
count =0
for ch in word:
    if ch=="i":
        count+=1
print(f"'i' EXIST {count} TIMES ")
# Out:
# 'i' EXIST 5 TIMES

# %%
word = "artificial intelligence"
count =0
if "i" in word:
    print(" 'i' exist")
# Out:
#  'i' exist

# %% [markdown]
# skip mutiples of 3

# %%
i=1
while(i<=10):
    # i+=1
    if(i%3==0):
        i+=1
        continue
    print(i)
    i+=1
# Out:
# 1
# 2
# 4
# 5
# 7
# 8
# 10

# %% [markdown]
# trafic light system by match case

# %%
button = input("enter the color : ")
match button:
    case "red" :
        print("stop")
    case "yellow" :
        print("look")
    case "green" :
        print("go")
    case _:
        print("wrong value")
# Out:
# go

# %%
user=input("admin")
password=input("pass")
if(user=="admin" and password =="pass"):
    print("Login Succesful !")
elif(user=="admin" and password!="pass"):
    print("Un-Authorize Login detected user = ",user +"passoword = ",password)
elif(user!="admin" and password=="pass"):
    print("Un-Authorize Login detected user = ",user +" passoword = ",password)
else:
    print("login failed !!")
# Out:
# Un-Authorize Login detected user =  adminpassoword =  sd

# %% [markdown]
# Practice Problems (Set 1)
# 1.For a given number , print if it’s a multiple of 5 or not.
# 2.For a given number n , print if it’s Odd or Even.

# %%
#1
n=int(input("enter a number"))
res="yes multiple" if n%5==0 else "not the multipe"
print(res)
# Out:
# yes multiple

# %%
#2
n=(int(input("enter a number")))
res = "even" if (n%2==0) else "odd"
print(res)
# Out:
# even

# %% [markdown]
# the arithmetic operation

# %%
a = 10
b = 20
print(a + b)
print(a-b)
print(a*b) # gives 200
print(a/b) # gives 0.5
print(a%b) # modulo gives reminder
print(a**b) # a to the power b
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 100000000000000000000
