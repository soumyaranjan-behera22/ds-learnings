# %% [markdown]
# File input and Output Operations
# r = read
# w = write
# a = append
# r+ = read and write
# w+ = write and read
# a+ = append and read
# b = binary mode like - images, videos etc
# t = textual based

# %%
f = open("sample.txt", "r" )
read =f.read()
print(read)
f.close()
# Out:
# hey this is soumya i am a b tech student
# recently learnign python form the one of the greatest mam
# shradha khapra who is the founder of apna college
# and i have decided to be a educator and an engineer like her

# %%
f = open("sample.txt" , "r")
readline = f.readline()
print(readline)
readline = f.readline()
input("hello")
print(readline)
# Out:
# hey this is soumya i am a b tech student
#
# recently learnign python form the one of the greatest mam

# %%
f = open("sample.txt" , "r")
readlines =f.readlines()
print(readlines)
f.close()
# Out:
# ['hey this is soumya i am a b tech student\n', 'recently learning python form the one of the greatest teacher\n', 'Shradha Khapra mam who is the founder of apna college \n', 'and i have decided to be a educator and an engineer like her']

# %% [markdown]
# write mode

# %%
f= open("sample.txt", "w")
write =f.write(" writen something in this file")

f.close()

# %%
f= open("sample.txt" , "w")
f.writelines(["soumya \n" , "omega\n"])
f.close()

# %%
f = open( "sampl2.txt" , "r")
count =0
for i in f:
    count+=1
    print(i)
print(count)
# Out:
#  And all the world grew still.
#
# Beneath that silver star I stood,
#
# Where shadows stretched and curled.
#
# I walked through paths of pine and wood,
#
# Across a dreaming world.
#
# The sky became a star-strewn sea,
#
# A map of ancient fire.
#
# It whispered secrets back to me,
#
# Of longing and desire
# 9

# %%
f = open("poem.txt", "w+")
# f.read()
f.write(""" And all the world grew still.
Beneath that silver star I stood,
Where shadows stretched and curled.
I walked through paths of pine and wood,
Across a dreaming world.
The sky became a star-strewn sea,
A map of ancient fire.
It whispered secrets back to me,
Of longing and desire """)
f.seek(0) # this seek give the pointer to 0th position for reading from the first 
poem = f.read()
f = open ("sampl2.txt" , "w+")
f.write(poem)
f.seek(0)
f.read()
# Out:
# ' And all the world grew still.\nBeneath that silver star I stood,\nWhere shadows stretched and curled.\nI walked through paths of pine and wood,\nAcross a dreaming world.\nThe sky became a star-strewn sea,\nA map of ancient fire.\nIt whispered secrets back to me,\nOf longing and desire '

# %%
import os
try :
    os.remove("sampel.txt")
except:
    print("not exist")
# Out:
# not exist

# %%
with open("poem.txt" , "r") as f :
    count=0
    for eachline in f:
        if "star" in eachline.split():
            count+=1
            print(eachline)
        # else:
        #     print("not present")
print(count)
# Out:
# Beneath that silver star I stood,
#
# I walked  star star through paths of pine and wood,
#
# 2

# %% [markdown]
# a random game which is guess game and store the heighest score in the text

# %%
import random
random_number = random.randint(0,100)
    
count=0
while(True):
    count+=1
    x = int(input())
    if x==random_number:
        print("win")
        break
    elif x<random_number:
        print("high please")
    elif x>random_number:
        print("lower please ")
print(count)
with open("heighest_score.txt" , "w+") as f :
    for score in f:
        if int(score) < count:
            no= f.write(str(count))

# if(count)
# Out:
# lower please
# lower please
# lower please
# lower please
# win
# 5

# %%
st ="34"
string_to_int = int(st)
print(string_to_int+3)
# Out:
# 37

# %%
count = 10
# score = 30

with open("heighest_score.txt" , "r") as f :
    hiscore = f.read()
    # print(int(score))
if int(hiscore) < count:
     with open("heighest_score.txt" , "w") as f:
        f.write(ḥiscore)
else:
     with open ("heighest_score.txt" , "w") as f:
          f.write("0")
